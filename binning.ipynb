# %% [markdown]
# # Binning
#
# Tip on creating a new features;
# We can categorise the elevation variables through binning.
# For example: Elevations from 0 - 100 can be categorised as steep, 100 - 120 very steep and maybe elevations with more than 120 can categorised as extremely steep.
# Experiment with different bins and choose the ones with the highest performance.
#
# ### Elevation
#
# in second argument of pd.cut you can configure the bins, and label is the name of respective bin
# so here 0-99 is bin 0, 100-199 is bin 1, 200-999 is bin 2, else it's NaN

# %%
import pandas as pd
import numpy as np
from dfcols import all_square_cols

train = pd.read_csv('./data/Train.csv')
test = pd.read_csv('./data/Test.csv')
sample_submission = pd.read_csv('./data/SampleSubmission.csv')

# elevationCols = all_square_cols("elevation")

# elevationCols = train[elevationCols]

# for col in elevationCols:
#     curCol = elevationCols[col]
#     elevationCols[col] = pd.cut(curCol, [0,100,200,1000], labels=[0,1,2]) # here

# train_binning = train.replace(elevationCols)

# train_binning.describe(include = 'all')
# Out:
# C:\Users\duowe\AppData\Local\Temp/ipykernel_12908/1298142667.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elevationCols[col] = pd.cut(curCol, [0,100,200,1000], labels=[0,1,2]) # here
#           Sample_ID   1_elevation   2_elevation   3_elevation   4_elevation  \
# count  10864.000000  10864.000000  10864.000000  10864.000000  10864.000000
# mean    5432.500000      1.232695      1.239875      1.239691      1.230762
# std     3136.310996      0.826790      0.832844      0.829352      0.832489
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2716.750000      0.000000      0.000000      0.000000      0.000000
# 50%     5432.500000      1.000000      1.000000      1.000000      1.000000
# ...

# %%
binningCols = train[all_square_cols("slope")]

def bin(i):
    if i  < 5: return 0
    elif i < 22: return 1
    elif i < 28: return 2
    elif i < 35: return 3
    elif i < 50: return 4
    else: return 5
x = 0
for col in binningCols:
    binned = list(map(bin, binningCols[col]))
    train["col"+str(x)] = binned
    x += 1

train.describe()
# Out:
#           Sample_ID   1_elevation   2_elevation   3_elevation   4_elevation  \
# count  10864.000000  10864.000000  10864.000000  10864.000000  10864.000000
# mean    5432.500000    225.017489    224.925074    224.801730    224.673417
# std     3136.310996    158.419265    158.337494    158.264168    158.217713
# min        1.000000      3.000000      3.000000      4.000000      2.000000
# 25%     2716.750000    101.750000    101.000000    101.000000    101.000000
# 50%     5432.500000    191.000000    192.000000    192.000000    191.000000
# 75%     8148.250000    312.000000    311.250000    312.000000    311.000000
# max    10864.000000    901.000000    904.000000    907.000000    909.000000
#
#         5_elevation   6_elevation   7_elevation   8_elevation   9_elevation  \
# count  10864.000000  10864.000000  10864.000000  10864.000000  10864.000000
# mean     224.586156    225.050994    224.940630    224.792710    224.655468
# ...
