# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn import svm

# %%
df = pd.read_csv('../Data/Train.csv')
#df.head(10)[["1_elevation","2_elevation","3_elevation","4_elevation","5_elevation","6_elevation","7_elevation","8_elevation","9_elevation",]]
df.head(10)
# Out:
#    Sample_ID  1_elevation  2_elevation  3_elevation  4_elevation  5_elevation  \
# 0          1          130          129          127          126          123
# 1          2          161          158          155          153          151
# 2          3          149          151          154          156          158
# 3          4           80           78           77           75           73
# 4          5          117          115          114          112          110
# 5          6          308          310          314          317          319
# 6          7          130          130          130          130          129
# 7          8          141          139          137          135          132
# 8          9          100          102          104          106          109
# 9         10          141          140          140          140          140
#
#    6_elevation  7_elevation  8_elevation  9_elevation  ...  17_sdoif  \
# ...

# %%
df_train = df.drop(labels=["Sample_ID","Label"], axis=1)
y_train = df["Label"]
df_train_t8 = df_train.head(800)
y_train_t8 = df_train.head(800)
Xtr = df_train_t8.to_numpy()
ytr = y_train_t8.to_numpy()

df_train_l2 = df_train.tail(200)
y_train_l2 = df_train.tail(200)
Xte = df_train_l2.to_numpy()
yte = y_train_l2.to_numpy()

# %%
dftrainsmall = df.head(1000).drop(labels=["Sample_ID","Label"], axis=1)
#dftrainsmall = df.head(1000)[["1_elevation","2_elevation","3_elevation","4_elevation","5_elevation","6_elevation","7_elevation","8_elevation","9_elevation"]]
dfoutsmall = df.head(1000)["Label"]
X = dftrainsmall.to_numpy()
y = dfoutsmall.to_numpy()

dftestsmall = df.iloc[1000:2000].drop(labels=["Sample_ID","Label"], axis=1)
dfouttestsmall = df.iloc[1000:2000]["Label"]
Xt = dftestsmall.to_numpy()
yt = dfouttestsmall.to_numpy()

clf = LogisticRegression(max_iter=10000).fit(X,y)
y_pred = clf.predict(Xt)
f1 = f1_score(yt, y_pred)
print(f1)
# Out:
# 0.5307692307692307
# /Applications/anaconda3/envs/StartHack/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
clf2 = LogisticRegression().fit(df_train.head(8000).to_numpy(), y_train.head(8000).to_numpy())
clf2.predict(df_train.tail(2000).to_numpy(), y_train.tail(2000).to_numpy())
# Out:
# /Applications/anaconda3/envs/StartHack/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 2>()
#       1 clf2 = LogisticRegression().fit(df_train.head(8000).to_numpy(), y_train.head(8000).to_numpy())
# ----> 2 clf2.predict(df_train.tail(2000).to_numpy(), y_train.tail(2000).to_numpy())
#
# ...

# %%
clf4 = svm.SVC()
clf4.fit(Xtr, ytr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [62], in <cell line: 2>()
#       1 clf4 = svm.SVC()
# ----> 2 clf4.fit(Xtr, ytr)
#
# File /Applications/anaconda3/envs/StartHack/lib/python3.9/site-packages/sklearn/svm/_base.py:190, in BaseLibSVM.fit(self, X, y, sample_weight)
#     188     check_consistent_length(X, y)
#     189 else:
# --> 190     X, y = self._validate_data(
#     191         X,
#     192         y,
#     193         dtype=np.float64,
#     194         order="C",
#     195         accept_sparse="csr",
#     196         accept_large_sparse=False,
#     197     )
#     199 y = self._validate_targets(y)
#     201 sample_weight = np.asarray(
#     202     [] if sample_weight is None else sample_weight, dtype=np.float64
#     203 )
#
# ...
